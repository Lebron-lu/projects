# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

from dataload import *
from model import *
import tensorflow as tf
import numpy as np
import time

tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
epochs = 300
train_img_dir = './dataset/train'
test_img_dir = './dataset/eval'
initial_lr = 0.001
dropout_rate = 0.5
lpr_len = 7
train_batch_size = 128
test_batch_size = 128
saved_model_folder = './saved_reduced_model'
pretrained_model = ''

# %%
def metric(test_dataset, lprnet):
    
    tp, tp_error = 0, 0  # tp为正确预测数量, tp_error是错误预测数量
    start_time = time.time()
    for cur_batch, (test_imgs, test_labels) in enumerate(test_dataset):
        test_labels = tf.cast(test_labels, tf.int32)
        prebs = lprnet(test_imgs)
        preb_labels = list()
        for i in range(prebs.shape[0]):
            preb = prebs[i, :, :]
            preb_label = list()
            for j in range(preb.shape[1]):
                preb_label.append(np.argmax(preb[:, j]))
            no_repeat_blank_label = list()
            pre_c = preb_label[0]
            if pre_c != len(CHARS) - 1:
                no_repeat_blank_label.append(pre_c)
            for c in preb_label:
                if (pre_c == c) or (c == len(CHARS) - 1):
                    if c == (len(CHARS) - 1):
                        pre_c = c
                    continue
                no_repeat_blank_label.append(c)
                pre_c = c
            preb_labels.append(no_repeat_blank_label)
        for i, label in enumerate(preb_labels):
            if len(label) != len(test_labels[i]):
                tp_error += 1
                continue
            if (np.asarray(test_labels[i]) == np.asarray(label)).all():
                tp += 1
            else:
                tp_error += 1
                
    end_time = time.time()
    t = end_time - start_time
    acc = tp * 1.0 / (tp + tp_error)  # 准确率
    
    return acc, tp, tp_error, t

# %%
# 加载训练数据集
tr_imgs, tr_labels, train_imgs_num = load_data(img_dir=train_img_dir, lpr_len=lpr_len)
tr_imgs = tr_imgs.map(preprocess,num_parallel_calls=4)
train_dataset = tf.data.Dataset.zip((tr_imgs, tr_labels)).shuffle(train_imgs_num).batch(train_batch_size).prefetch(tf.data.experimental.AUTOTUNE).cache()

# 加载测试数据集
te_imgs, te_labels, test_imgs_num = load_data(img_dir=test_img_dir, lpr_len=lpr_len)
te_imgs = te_imgs.map(preprocess,num_parallel_calls=4)
test_dataset = tf.data.Dataset.zip((te_imgs, te_labels)).batch(test_batch_size).prefetch(tf.data.experimental.AUTOTUNE).cache()

# %%
# 训练模型
if not os.path.exists(saved_model_folder):
    os.mkdir(saved_model_folder)

# 实例化模型
lprnet = LPRNet(lpr_len=lpr_len, class_num=len(CHARS), dropout_rate=dropout_rate)
print("********** Successful to build network! **********\n")

# 加载预训练模型
if pretrained_model:
    lprnet.load_weights(pretrained_model)
    print("********** Successful to load pretrained model! **********")

# 优化器使用 Adam
optimizer = tf.keras.optimizers.Adam(learning_rate=initial_lr)

# 模型训练
top_acc = 0.
for cur_epoch in range(1, epochs + 1):
    batch = 0
    for batch_index, (train_imgs, train_labels) in enumerate(train_dataset):  # 修改的地方
        start_time = time.time()
        with tf.GradientTape() as tape:
            train_logits = lprnet(train_imgs) #[N,66,18]
            train_labels = tf.cast(train_labels, tf.int32) #[N,7]
            train_logits = tf.transpose(train_logits, [2, 0, 1]) #[18,N,66]
            logits_shape = train_logits.shape
            logit_length = tf.fill([logits_shape[1]], logits_shape[0]) #(N)
            label_length = tf.fill([logits_shape[1]], lpr_len)
            loss = tf.nn.ctc_loss(labels=train_labels,
                                  logits=train_logits,
                                  label_length=label_length,
                                  logit_length=logit_length,
                                  logits_time_major=True,
                                  blank_index=len(CHARS) - 1)
            loss = tf.reduce_mean(loss)
        grads = tape.gradient(loss, lprnet.variables)
        optimizer.apply_gradients(grads_and_vars=zip(grads, lprnet.variables))
        end_time = time.time()
        batch = batch + int(np.shape(train_imgs)[0])
        print('\r' + "Epoch {0}/{1} || ".format(cur_epoch, epochs) 
                  + "Batch {0}/{1} || ".format(batch, train_imgs_num) # 修改的地方
                  + "Loss:{} || ".format(loss) 
                  + "A Batch time:{0:.4f}s || ".format(end_time - start_time)
                  + "Learning rate:{0:.8f} || ".format(optimizer.lr.numpy().item()), end=''*20)
    acc, tp, tp_error, t = metric(test_dataset, lprnet) # 修改的地方
    print("\n******* Prediction {0}/{1} || Acc:{2:.2f}% *******".format(tp, tp + tp_error, acc*100))
    print("******* Test speed: {}s 1/{} *******".format(t / (tp + tp_error), tp + tp_error))
        
    # 保存模型
    if acc >= top_acc:
        top_acc = acc
        lprnet.save(saved_model_folder, save_format='tf')

# 将.pb模型转为.tflite
cvtmodel = tf.keras.models.load_model(saved_model_folder)
converter = tf.lite.TFLiteConverter.from_keras_model(cvtmodel)
tflite_model = converter.convert()
with open('lprnet' + '{}'.format(np.around(top_acc * 100)) + '.tflite', "wb") as f:
    f.write(tflite_model)
print("\n ********** Successful to convert tflite model! ********** \n")
# Out:
# ********** Successful to build network! **********
#
# Epoch 1/300 || Batch 208075/208075 || Loss:13.095730781555176 || A Batch time:0.7216s || Learning rate:0.00100000 ||
# ******* Prediction 221/6436 || Acc:3.43% *******
# ******* Test speed: 0.007432138349344599s 1/6436 *******
# Epoch 2/300 || Batch 208075/208075 || Loss:5.929137706756592 || A Batch time:0.1720s || Learning rate:0.00100000 ||
# ******* Prediction 2849/6436 || Acc:44.27% *******
# ******* Test speed: 0.007605572751473758s 1/6436 *******
# Epoch 3/300 || Batch 208075/208075 || Loss:3.994891881942749 || A Batch time:0.1564s || Learning rate:0.00100000 ||
# ******* Prediction 3876/6436 || Acc:60.22% *******
# ******* Test speed: 0.007074955496601321s 1/6436 *******
# Epoch 4/300 || Batch 208075/208075 || Loss:2.946272850036621 || A Batch time:0.1367s || Learning rate:0.00100000 ||
# ******* Prediction 4183/6436 || Acc:64.99% *******
# ******* Test speed: 0.007110061039459342s 1/6436 *******
# Epoch 5/300 || Batch 208075/208075 || Loss:2.6088128089904785 || A Batch time:0.1431s || Learning rate:0.00100000 ||
# ******* Prediction 4383/6436 || Acc:68.10% *******
# ******* Test speed: 0.007143472350851359s 1/6436 *******
# Epoch 6/300 || Batch 208075/208075 || Loss:2.350031852722168 || A Batch time:0.1562s || Learning rate:0.00100000 ||
# ******* Prediction 4626/6436 || Acc:71.88% *******
# ******* Test speed: 0.007232067709461067s 1/6436 *******
# Epoch 7/300 || Batch 208075/208075 || Loss:2.1516377925872803 || A Batch time:0.1757s || Learning rate:0.00100000 ||
# ******* Prediction 4730/6436 || Acc:73.49% *******
# ******* Test speed: 0.00785554144380995s 1/6436 *******
# Epoch 8/300 || Batch 208075/208075 || Loss:1.9867055416107178 || A Batch time:0.1367s || Learning rate:0.00100000 ||
# ******* Prediction 4835/6436 || Acc:75.12% *******
# ******* Test speed: 0.007102103949037674s 1/6436 *******
# Epoch 9/300 || Batch 208075/208075 || Loss:1.8062036037445068 || A Batch time:0.2180s || Learning rate:0.00100000 ||
# ******* Prediction 4910/6436 || Acc:76.29% *******
# ******* Test speed: 0.00918761960759231s 1/6436 *******
# Epoch 10/300 || Batch 208075/208075 || Loss:1.696541666984558 || A Batch time:0.2263s || Learning rate:0.00100000 ||
# ******* Prediction 4926/6436 || Acc:76.54% *******
# ******* Test speed: 0.009460377685767364s 1/6436 *******
# Epoch 11/300 || Batch 208075/208075 || Loss:1.6028116941452026 || A Batch time:0.2270s || Learning rate:0.00100000 ||
# ******* Prediction 5008/6436 || Acc:77.81% *******
# ******* Test speed: 0.009039235974484307s 1/6436 *******
# Epoch 12/300 || Batch 208075/208075 || Loss:1.5265289545059204 || A Batch time:0.1607s || Learning rate:0.00100000 ||
# ******* Prediction 5061/6436 || Acc:78.64% *******
# ******* Test speed: 0.007942600158373713s 1/6436 *******
# Epoch 13/300 || Batch 208075/208075 || Loss:1.4483615159988403 || A Batch time:0.1368s || Learning rate:0.00100000 ||
# ******* Prediction 5111/6436 || Acc:79.41% *******
# ******* Test speed: 0.007113447020408009s 1/6436 *******
# Epoch 14/300 || Batch 208075/208075 || Loss:1.3937395811080933 || A Batch time:0.1362s || Learning rate:0.00100000 ||
# ******* Prediction 5150/6436 || Acc:80.02% *******
# ******* Test speed: 0.007148226978913682s 1/6436 *******
# Epoch 15/300 || Batch 208075/208075 || Loss:1.2880151271820068 || A Batch time:0.1587s || Learning rate:0.00100000 ||
# ******* Prediction 5201/6436 || Acc:80.81% *******
# ******* Test speed: 0.00712540595704832s 1/6436 *******
# Epoch 16/300 || Batch 208075/208075 || Loss:1.2583781480789185 || A Batch time:0.1612s || Learning rate:0.00100000 ||
# ******* Prediction 5211/6436 || Acc:80.97% *******
# ******* Test speed: 0.007264398876519734s 1/6436 *******
# Epoch 17/300 || Batch 208075/208075 || Loss:1.1666337251663208 || A Batch time:0.1437s || Learning rate:0.00100000 ||
# ******* Prediction 5224/6436 || Acc:81.17% *******
# ******* Test speed: 0.007224423385985228s 1/6436 *******
# Epoch 18/300 || Batch 208075/208075 || Loss:1.1542906761169434 || A Batch time:0.1417s || Learning rate:0.00100000 ||
# ******* Prediction 5233/6436 || Acc:81.31% *******
# ******* Test speed: 0.007120913381973655s 1/6436 *******
# Epoch 19/300 || Batch 208075/208075 || Loss:1.1206539869308472 || A Batch time:0.1440s || Learning rate:0.00100000 ||
# ******* Prediction 5259/6436 || Acc:81.71% *******
# ******* Test speed: 0.0070159059640707774s 1/6436 *******
# Epoch 20/300 || Batch 208075/208075 || Loss:1.0860319137573242 || A Batch time:0.1394s || Learning rate:0.00100000 ||
# ******* Prediction 5235/6436 || Acc:81.34% *******
# ******* Test speed: 0.007344028311089894s 1/6436 *******
# Epoch 21/300 || Batch 208075/208075 || Loss:1.0132379531860352 || A Batch time:0.1854s || Learning rate:0.00100000 ||
# ******* Prediction 5254/6436 || Acc:81.63% *******
# ******* Test speed: 0.007074977871495941s 1/6436 *******
# Epoch 22/300 || Batch 208075/208075 || Loss:1.0435158014297485 || A Batch time:0.1573s || Learning rate:0.00100000 ||
# ******* Prediction 5232/6436 || Acc:81.29% *******
# ******* Test speed: 0.007157296331274057s 1/6436 *******
# Epoch 23/300 || Batch 208075/208075 || Loss:1.0629435777664185 || A Batch time:0.1454s || Learning rate:0.00100000 ||
# ******* Prediction 5234/6436 || Acc:81.32% *******
# ******* Test speed: 0.007172220608253076s 1/6436 *******
# Epoch 24/300 || Batch 208075/208075 || Loss:1.039475917816162 || A Batch time:0.1381s || Learning rate:0.00100000 ||
# ******* Prediction 5270/6436 || Acc:81.88% *******
# ******* Test speed: 0.007174314587215521s 1/6436 *******
# Epoch 25/300 || Batch 208075/208075 || Loss:1.0063445568084717 || A Batch time:0.1710s || Learning rate:0.00100000 ||
# ******* Prediction 5258/6436 || Acc:81.70% *******
# ******* Test speed: 0.007049353208654486s 1/6436 *******
# Epoch 26/300 || Batch 208075/208075 || Loss:1.0012708902359009 || A Batch time:0.1668s || Learning rate:0.00100000 ||
# ******* Prediction 5261/6436 || Acc:81.74% *******
# ******* Test speed: 0.007227111485079996s 1/6436 *******
# Epoch 27/300 || Batch 208075/208075 || Loss:0.9930316209793091 || A Batch time:0.1412s || Learning rate:0.00100000 ||
# ******* Prediction 5276/6436 || Acc:81.98% *******
# ******* Test speed: 0.007426162326165502s 1/6436 *******
# Epoch 28/300 || Batch 208075/208075 || Loss:0.9532060623168945 || A Batch time:0.1665s || Learning rate:0.00100000 ||
# ******* Prediction 5299/6436 || Acc:82.33% *******
# ******* Test speed: 0.007340307929191329s 1/6436 *******
# Epoch 29/300 || Batch 208075/208075 || Loss:0.974860429763794 || A Batch time:0.1377s || Learning rate:0.00100000 ||
# ******* Prediction 5302/6436 || Acc:82.38% *******
# ******* Test speed: 0.007158686130812926s 1/6436 *******
# Epoch 30/300 || Batch 208075/208075 || Loss:0.9258338212966919 || A Batch time:0.1438s || Learning rate:0.00100000 ||
# ******* Prediction 5312/6436 || Acc:82.54% *******
# ******* Test speed: 0.007026292323473449s 1/6436 *******
# Epoch 31/300 || Batch 208075/208075 || Loss:0.9219555854797363 || A Batch time:0.1652s || Learning rate:0.00100000 ||
# ******* Prediction 5320/6436 || Acc:82.66% *******
# ******* Test speed: 0.007271804151659504s 1/6436 *******
# Epoch 32/300 || Batch 208075/208075 || Loss:0.8942667841911316 || A Batch time:0.1378s || Learning rate:0.00100000 ||
# ******* Prediction 5336/6436 || Acc:82.91% *******
# ******* Test speed: 0.007346112621430657s 1/6436 *******
# Epoch 33/300 || Batch 208075/208075 || Loss:0.9261969923973083 || A Batch time:0.1767s || Learning rate:0.00100000 ||
# ******* Prediction 5357/6436 || Acc:83.23% *******
# ******* Test speed: 0.007924528244936073s 1/6436 *******
# Epoch 34/300 || Batch 208075/208075 || Loss:0.910532534122467 || A Batch time:0.1429s || Learning rate:0.00100000 ||
# ******* Prediction 5356/6436 || Acc:83.22% *******
# ******* Test speed: 0.007237566339814048s 1/6436 *******
# Epoch 35/300 || Batch 208075/208075 || Loss:0.898169755935669 || A Batch time:0.1420s || Learning rate:0.00100000 ||
# ******* Prediction 5341/6436 || Acc:82.99% *******
# ******* Test speed: 0.007181251989972747s 1/6436 *******
# Epoch 36/300 || Batch 208075/208075 || Loss:0.8761752247810364 || A Batch time:0.1362s || Learning rate:0.00100000 ||
# ******* Prediction 5344/6436 || Acc:83.03% *******
# ******* Test speed: 0.007073342614917743s 1/6436 *******
# Epoch 37/300 || Batch 208075/208075 || Loss:0.8852901458740234 || A Batch time:0.1684s || Learning rate:0.00100000 ||
# ******* Prediction 5346/6436 || Acc:83.06% *******
# ******* Test speed: 0.00709515591450105s 1/6436 *******
# Epoch 38/300 || Batch 208075/208075 || Loss:0.8256071209907532 || A Batch time:0.1423s || Learning rate:0.00100000 ||
# ******* Prediction 5372/6436 || Acc:83.47% *******
# ******* Test speed: 0.007141555185418754s 1/6436 *******
# Epoch 39/300 || Batch 208075/208075 || Loss:0.7761783599853516 || A Batch time:0.1570s || Learning rate:0.00100000 ||
# ******* Prediction 5360/6436 || Acc:83.28% *******
# ******* Test speed: 0.007014059405507621s 1/6436 *******
# Epoch 40/300 || Batch 208075/208075 || Loss:0.7253499031066895 || A Batch time:0.1444s || Learning rate:0.00100000 ||
# ******* Prediction 5364/6436 || Acc:83.34% *******
# ******* Test speed: 0.007159635545008667s 1/6436 *******
# Epoch 41/300 || Batch 208075/208075 || Loss:0.7408726811408997 || A Batch time:0.1439s || Learning rate:0.00100000 ||
# ******* Prediction 5370/6436 || Acc:83.44% *******
# ******* Test speed: 0.007038329238844184s 1/6436 *******
# Epoch 42/300 || Batch 208075/208075 || Loss:0.7221293449401855 || A Batch time:0.1426s || Learning rate:0.00100000 ||
# ******* Prediction 5369/6436 || Acc:83.42% *******
# ******* Test speed: 0.007392704153446176s 1/6436 *******
# Epoch 43/300 || Batch 208075/208075 || Loss:0.7185245156288147 || A Batch time:0.1426s || Learning rate:0.00100000 ||
# ******* Prediction 5377/6436 || Acc:83.55% *******
# ******* Test speed: 0.007285915116036879s 1/6436 *******
# Epoch 44/300 || Batch 208075/208075 || Loss:0.5831342339515686 || A Batch time:0.1443s || Learning rate:0.00100000 ||
# ******* Prediction 5389/6436 || Acc:83.73% *******
# ******* Test speed: 0.007014782070150429s 1/6436 *******
# Epoch 45/300 || Batch 208075/208075 || Loss:0.5880250930786133 || A Batch time:0.1517s || Learning rate:0.00100000 ||
# ******* Prediction 5376/6436 || Acc:83.53% *******
# ******* Test speed: 0.007027493418189144s 1/6436 *******
# Epoch 46/300 || Batch 208075/208075 || Loss:0.5872111320495605 || A Batch time:0.1692s || Learning rate:0.00100000 ||
# ******* Prediction 5391/6436 || Acc:83.76% *******
# ******* Test speed: 0.007087911597833343s 1/6436 *******
# Epoch 47/300 || Batch 208075/208075 || Loss:0.5762528777122498 || A Batch time:0.1423s || Learning rate:0.00100000 ||
# ******* Prediction 5391/6436 || Acc:83.76% *******
# ******* Test speed: 0.007026005450652356s 1/6436 *******
# Epoch 48/300 || Batch 208075/208075 || Loss:0.5653343200683594 || A Batch time:0.1572s || Learning rate:0.00100000 ||
# ******* Prediction 5391/6436 || Acc:83.76% *******
# ******* Test speed: 0.007029570727114206s 1/6436 *******
# Epoch 49/300 || Batch 208075/208075 || Loss:0.5876098871231079 || A Batch time:0.1404s || Learning rate:0.00100000 ||
# ******* Prediction 5387/6436 || Acc:83.70% *******
# ******* Test speed: 0.007160389845677975s 1/6436 *******
# Epoch 50/300 || Batch 208075/208075 || Loss:0.5587406754493713 || A Batch time:0.1496s || Learning rate:0.00100000 ||
# ******* Prediction 5390/6436 || Acc:83.75% *******
# ******* Test speed: 0.007232011846313571s 1/6436 *******
# Epoch 51/300 || Batch 208075/208075 || Loss:0.5519182085990906 || A Batch time:0.1422s || Learning rate:0.00100000 ||
# ******* Prediction 5420/6436 || Acc:84.21% *******
# ******* Test speed: 0.006952966385705638s 1/6436 *******
# Epoch 52/300 || Batch 208075/208075 || Loss:0.5421949028968811 || A Batch time:0.1384s || Learning rate:0.00100000 ||
# ******* Prediction 5408/6436 || Acc:84.03% *******
# ******* Test speed: 0.007083193569764208s 1/6436 *******
# Epoch 53/300 || Batch 208075/208075 || Loss:0.5868496894836426 || A Batch time:0.1380s || Learning rate:0.00100000 ||
# ******* Prediction 5407/6436 || Acc:84.01% *******
# ******* Test speed: 0.007027813408817839s 1/6436 *******
# Epoch 54/300 || Batch 208075/208075 || Loss:0.5574720501899719 || A Batch time:0.1419s || Learning rate:0.00100000 ||
# ******* Prediction 5412/6436 || Acc:84.09% *******
# ******* Test speed: 0.007099758622956024s 1/6436 *******
# Epoch 55/300 || Batch 208075/208075 || Loss:0.5514233112335205 || A Batch time:0.1418s || Learning rate:0.00100000 ||
# ******* Prediction 5396/6436 || Acc:83.84% *******
# ******* Test speed: 0.0070506601025407695s 1/6436 *******
# Epoch 56/300 || Batch 208075/208075 || Loss:0.5745187401771545 || A Batch time:0.1416s || Learning rate:0.00100000 ||
# ******* Prediction 5402/6436 || Acc:83.93% *******
# ******* Test speed: 0.007108913362952328s 1/6436 *******
# Epoch 57/300 || Batch 208075/208075 || Loss:0.5655511617660522 || A Batch time:0.1402s || Learning rate:0.00100000 ||
# ******* Prediction 5403/6436 || Acc:83.95% *******
# ******* Test speed: 0.007088225179758777s 1/6436 *******
# Epoch 58/300 || Batch 208075/208075 || Loss:0.5812948346138 || A Batch time:0.1439s || Learning rate:0.00100000 || ||
# ******* Prediction 5414/6436 || Acc:84.12% *******
# ******* Test speed: 0.007102732853981336s 1/6436 *******
# Epoch 59/300 || Batch 208075/208075 || Loss:0.531761109828949 || A Batch time:0.1466s || Learning rate:0.00100000 ||
# ******* Prediction 5416/6436 || Acc:84.15% *******
# ******* Test speed: 0.00707080962125969s 1/6436 *******
# Epoch 60/300 || Batch 208075/208075 || Loss:0.5409837961196899 || A Batch time:0.1367s || Learning rate:0.00100000 ||
# ******* Prediction 5420/6436 || Acc:84.21% *******
# ******* Test speed: 0.007114028508356449s 1/6436 *******
# Epoch 61/300 || Batch 208075/208075 || Loss:0.5107635259628296 || A Batch time:0.1451s || Learning rate:0.00100000 ||
# ******* Prediction 5430/6436 || Acc:84.37% *******
# ******* Test speed: 0.007083924939870982s 1/6436 *******
# Epoch 62/300 || Batch 208075/208075 || Loss:0.5312951803207397 || A Batch time:0.1394s || Learning rate:0.00100000 ||
# ******* Prediction 5416/6436 || Acc:84.15% *******
# ******* Test speed: 0.0071535579827796455s 1/6436 *******
# Epoch 63/300 || Batch 208075/208075 || Loss:0.49058908224105835 || A Batch time:0.1424s || Learning rate:0.00100000 ||
# ******* Prediction 5420/6436 || Acc:84.21% *******
# ******* Test speed: 0.007175217399395646s 1/6436 *******
# Epoch 64/300 || Batch 208075/208075 || Loss:0.48826146125793457 || A Batch time:0.1421s || Learning rate:0.00100000 ||
# ******* Prediction 5413/6436 || Acc:84.11% *******
# ******* Test speed: 0.007153806996093617s 1/6436 *******
# Epoch 65/300 || Batch 208075/208075 || Loss:0.47387897968292236 || A Batch time:0.1421s || Learning rate:0.00100000 ||
# ******* Prediction 5397/6436 || Acc:83.86% *******
# ******* Test speed: 0.00774151638770711s 1/6436 *******
# Epoch 66/300 || Batch 208075/208075 || Loss:0.44903793931007385 || A Batch time:0.1371s || Learning rate:0.00100000 ||
# ******* Prediction 5415/6436 || Acc:84.14% *******
# ******* Test speed: 0.007124731190979592s 1/6436 *******
# Epoch 67/300 || Batch 208075/208075 || Loss:0.4668291211128235 || A Batch time:0.1418s || Learning rate:0.00100000 ||
# ******* Prediction 5419/6436 || Acc:84.20% *******
# ******* Test speed: 0.007099670419936005s 1/6436 *******
# Epoch 68/300 || Batch 208075/208075 || Loss:0.4674075245857239 || A Batch time:0.1388s || Learning rate:0.00100000 ||
# ******* Prediction 5408/6436 || Acc:84.03% *******
# ******* Test speed: 0.007191455312364956s 1/6436 *******
# Epoch 69/300 || Batch 208075/208075 || Loss:0.4452778100967407 || A Batch time:0.1434s || Learning rate:0.00100000 ||
# ******* Prediction 5418/6436 || Acc:84.18% *******
# ******* Test speed: 0.0070341257222177375s 1/6436 *******
# Epoch 70/300 || Batch 208075/208075 || Loss:0.42901986837387085 || A Batch time:0.1422s || Learning rate:0.00100000 ||
# ******* Prediction 5409/6436 || Acc:84.04% *******
# ******* Test speed: 0.007074722153122489s 1/6436 *******
# Epoch 71/300 || Batch 208075/208075 || Loss:0.45353662967681885 || A Batch time:0.1549s || Learning rate:0.00100000 ||
# ******* Prediction 5409/6436 || Acc:84.04% *******
# ******* Test speed: 0.0071807696702244714s 1/6436 *******
# Epoch 72/300 || Batch 208075/208075 || Loss:0.5011627674102783 || A Batch time:0.1425s || Learning rate:0.00100000 ||
# ******* Prediction 5410/6436 || Acc:84.06% *******
# ******* Test speed: 0.007034378106583713s 1/6436 *******
# Epoch 73/300 || Batch 208075/208075 || Loss:0.4741989076137543 || A Batch time:0.1425s || Learning rate:0.00100000 ||
# ******* Prediction 5416/6436 || Acc:84.15% *******
# ******* Test speed: 0.007138008097819915s 1/6436 *******
# Epoch 74/300 || Batch 208075/208075 || Loss:0.513117253780365 || A Batch time:0.1388s || Learning rate:0.00100000 ||
# ******* Prediction 5412/6436 || Acc:84.09% *******
# ******* Test speed: 0.007110247373432754s 1/6436 *******
# Epoch 75/300 || Batch 208075/208075 || Loss:0.4764088988304138 || A Batch time:0.1528s || Learning rate:0.00100000 ||
# ******* Prediction 5405/6436 || Acc:83.98% *******
# ******* Test speed: 0.007138868716283197s 1/6436 *******
# Epoch 76/300 || Batch 208075/208075 || Loss:0.4878706932067871 || A Batch time:0.1535s || Learning rate:0.00100000 ||
# ******* Prediction 5400/6436 || Acc:83.90% *******
# ******* Test speed: 0.007010970077135312s 1/6436 *******
# Epoch 77/300 || Batch 208075/208075 || Loss:0.4463517665863037 || A Batch time:0.1712s || Learning rate:0.00100000 ||
# ******* Prediction 5387/6436 || Acc:83.70% *******
# ******* Test speed: 0.0071393494431167895s 1/6436 *******
# Epoch 78/300 || Batch 208075/208075 || Loss:0.5049071907997131 || A Batch time:0.1380s || Learning rate:0.00100000 ||
# ******* Prediction 5387/6436 || Acc:83.70% *******
# ******* Test speed: 0.007298785718499391s 1/6436 *******
# Epoch 79/300 || Batch 208075/208075 || Loss:0.4678761661052704 || A Batch time:0.1486s || Learning rate:0.00100000 ||
# ******* Prediction 5400/6436 || Acc:83.90% *******
# ******* Test speed: 0.007056831202201772s 1/6436 *******
# Epoch 80/300 || Batch 208075/208075 || Loss:0.4327937960624695 || A Batch time:0.1377s || Learning rate:0.00100000 ||
# ******* Prediction 5428/6436 || Acc:84.34% *******
# ******* Test speed: 0.0070648382286465335s 1/6436 *******
# Epoch 81/300 || Batch 208075/208075 || Loss:0.494645893573761 || A Batch time:0.1396s || Learning rate:0.00100000 ||
# ******* Prediction 5403/6436 || Acc:83.95% *******
# ******* Test speed: 0.0071763851169920475s 1/6436 *******
# Epoch 82/300 || Batch 208075/208075 || Loss:0.4546784460544586 || A Batch time:0.1374s || Learning rate:0.00100000 ||
# ******* Prediction 5392/6436 || Acc:83.78% *******
# ******* Test speed: 0.00705339591498698s 1/6436 *******
# Epoch 83/300 || Batch 208075/208075 || Loss:0.4672039747238159 || A Batch time:0.1427s || Learning rate:0.00100000 ||
# ******* Prediction 5400/6436 || Acc:83.90% *******
# ******* Test speed: 0.007102225306909821s 1/6436 *******
# Epoch 84/300 || Batch 208075/208075 || Loss:0.501034677028656 || A Batch time:0.1379s || Learning rate:0.00100000 ||
# ******* Prediction 5389/6436 || Acc:83.73% *******
# ******* Test speed: 0.0070316512589131625s 1/6436 *******
# Epoch 85/300 || Batch 208075/208075 || Loss:0.4864334762096405 || A Batch time:0.1365s || Learning rate:0.00100000 ||
# ******* Prediction 5385/6436 || Acc:83.67% *******
# ******* Test speed: 0.0070897471171273s 1/6436 *******
# Epoch 86/300 || Batch 208075/208075 || Loss:0.49773138761520386 || A Batch time:0.1442s || Learning rate:0.00100000 ||
# ******* Prediction 5401/6436 || Acc:83.92% *******
# ******* Test speed: 0.007089822021161939s 1/6436 *******
# Epoch 87/300 || Batch 208075/208075 || Loss:0.46566885709762573 || A Batch time:0.1443s || Learning rate:0.00100000 ||
# ******* Prediction 5410/6436 || Acc:84.06% *******
# ******* Test speed: 0.007058061821405898s 1/6436 *******
# Epoch 88/300 || Batch 208075/208075 || Loss:0.4852840304374695 || A Batch time:0.1473s || Learning rate:0.00100000 ||
# ******* Prediction 5375/6436 || Acc:83.51% *******
# ******* Test speed: 0.007117900291238978s 1/6436 *******
# Epoch 89/300 || Batch 208075/208075 || Loss:0.47863683104515076 || A Batch time:0.1414s || Learning rate:0.00100000 ||
# ******* Prediction 5407/6436 || Acc:84.01% *******
# ******* Test speed: 0.007158939626514727s 1/6436 *******
# Epoch 90/300 || Batch 208075/208075 || Loss:0.4771467447280884 || A Batch time:0.1590s || Learning rate:0.00100000 ||
# ******* Prediction 5408/6436 || Acc:84.03% *******
# ******* Test speed: 0.007173909764618811s 1/6436 *******
# Epoch 91/300 || Batch 208075/208075 || Loss:0.4489867687225342 || A Batch time:0.1365s || Learning rate:0.00100000 ||
# ******* Prediction 5393/6436 || Acc:83.79% *******
# ******* Test speed: 0.007219799006481657s 1/6436 *******
# Epoch 92/300 || Batch 208075/208075 || Loss:0.4405604600906372 || A Batch time:0.1409s || Learning rate:0.00100000 ||
# ******* Prediction 5409/6436 || Acc:84.04% *******
# ******* Test speed: 0.007093729255657303s 1/6436 *******
# Epoch 93/300 || Batch 208075/208075 || Loss:0.4331328868865967 || A Batch time:0.1721s || Learning rate:0.00100000 ||
# ******* Prediction 5406/6436 || Acc:84.00% *******
# ******* Test speed: 0.007081448439117394s 1/6436 *******
# Epoch 94/300 || Batch 208075/208075 || Loss:0.420682817697525 || A Batch time:0.1415s || Learning rate:0.00100000 ||
# ******* Prediction 5412/6436 || Acc:84.09% *******
# ******* Test speed: 0.007264489783790261s 1/6436 *******
# Epoch 95/300 || Batch 208075/208075 || Loss:0.46252262592315674 || A Batch time:0.1542s || Learning rate:0.00100000 ||
# ******* Prediction 5410/6436 || Acc:84.06% *******
# ******* Test speed: 0.007172111697342175s 1/6436 *******
# Epoch 96/300 || Batch 208075/208075 || Loss:0.4625333547592163 || A Batch time:0.1380s || Learning rate:0.00100000 ||
# ******* Prediction 5405/6436 || Acc:83.98% *******
# ******* Test speed: 0.007292277624771564s 1/6436 *******
# Epoch 97/300 || Batch 208075/208075 || Loss:0.45783326029777527 || A Batch time:0.1429s || Learning rate:0.00100000 ||
# ******* Prediction 5408/6436 || Acc:84.03% *******
# ******* Test speed: 0.007154008407189729s 1/6436 *******
# Epoch 98/300 || Batch 208075/208075 || Loss:0.4921445846557617 || A Batch time:0.1565s || Learning rate:0.00100000 ||
# ******* Prediction 5400/6436 || Acc:83.90% *******
# ******* Test speed: 0.007159155559065625s 1/6436 *******
# Epoch 99/300 || Batch 208075/208075 || Loss:0.4592021703720093 || A Batch time:0.1366s || Learning rate:0.00100000 ||
# ******* Prediction 5398/6436 || Acc:83.87% *******
# ******* Test speed: 0.007108903472063481s 1/6436 *******
# Epoch 100/300 || Batch 208075/208075 || Loss:0.4549952745437622 || A Batch time:0.1449s || Learning rate:0.00100000 ||
# ******* Prediction 5392/6436 || Acc:83.78% *******
# ******* Test speed: 0.007085583423367934s 1/6436 *******
# Epoch 101/300 || Batch 208075/208075 || Loss:0.4641728699207306 || A Batch time:0.1373s || Learning rate:0.00100000 ||
# ******* Prediction 5396/6436 || Acc:83.84% *******
# ******* Test speed: 0.0071427869159587055s 1/6436 *******
# Epoch 102/300 || Batch 208075/208075 || Loss:0.453909307718277 || A Batch time:0.1421s || Learning rate:0.00100000 ||
# ******* Prediction 5397/6436 || Acc:83.86% *******
# ******* Test speed: 0.007137839285908018s 1/6436 *******
# Epoch 103/300 || Batch 208075/208075 || Loss:0.4617246389389038 || A Batch time:0.1384s || Learning rate:0.00100000 ||
# ******* Prediction 5387/6436 || Acc:83.70% *******
# ******* Test speed: 0.0071063056504822725s 1/6436 *******
# Epoch 104/300 || Batch 208075/208075 || Loss:0.45229727029800415 || A Batch time:0.1382s || Learning rate:0.00100000 ||
# ******* Prediction 5395/6436 || Acc:83.83% *******
# ******* Test speed: 0.007142383797410262s 1/6436 *******
# Epoch 105/300 || Batch 208075/208075 || Loss:0.4684750735759735 || A Batch time:0.1447s || Learning rate:0.00100000 ||
# ******* Prediction 5372/6436 || Acc:83.47% *******
# ******* Test speed: 0.00724417374992015s 1/6436 *******
# Epoch 106/300 || Batch 208075/208075 || Loss:0.4414401650428772 || A Batch time:0.1383s || Learning rate:0.00100000 ||
# ******* Prediction 5379/6436 || Acc:83.58% *******
# ******* Test speed: 0.007029179722126261s 1/6436 *******
# Epoch 107/300 || Batch 208075/208075 || Loss:0.4535655677318573 || A Batch time:0.1886s || Learning rate:0.00100000 ||
# ******* Prediction 5358/6436 || Acc:83.25% *******
# ******* Test speed: 0.007089338701211421s 1/6436 *******
# Epoch 108/300 || Batch 208075/208075 || Loss:0.4242841899394989 || A Batch time:0.1483s || Learning rate:0.00100000 ||
# ******* Prediction 5352/6436 || Acc:83.16% *******
# ******* Test speed: 0.007054337994366273s 1/6436 *******
# Epoch 109/300 || Batch 208075/208075 || Loss:0.43089157342910767 || A Batch time:0.1374s || Learning rate:0.00100000 ||
# ******* Prediction 5364/6436 || Acc:83.34% *******
# ******* Test speed: 0.007138236662554696s 1/6436 *******
# Epoch 110/300 || Batch 208075/208075 || Loss:0.4038713872432709 || A Batch time:0.1383s || Learning rate:0.00100000 ||
# ******* Prediction 5370/6436 || Acc:83.44% *******
# ******* Test speed: 0.007099379620394994s 1/6436 *******
# Epoch 111/300 || Batch 208075/208075 || Loss:0.40903979539871216 || A Batch time:0.1420s || Learning rate:0.00100000 ||
# ******* Prediction 5385/6436 || Acc:83.67% *******
# ******* Test speed: 0.007065709182532994s 1/6436 *******
# Epoch 112/300 || Batch 208075/208075 || Loss:0.39524638652801514 || A Batch time:0.1432s || Learning rate:0.00100000 ||
# ******* Prediction 5380/6436 || Acc:83.59% *******
# ******* Test speed: 0.007073337206416726s 1/6436 *******
# Epoch 113/300 || Batch 208075/208075 || Loss:0.38290753960609436 || A Batch time:0.1790s || Learning rate:0.00100000 ||
# ******* Prediction 5376/6436 || Acc:83.53% *******
# ******* Test speed: 0.007019151064681295s 1/6436 *******
# Epoch 114/300 || Batch 208075/208075 || Loss:0.39814987778663635 || A Batch time:0.1486s || Learning rate:0.00100000 ||
# ******* Prediction 5364/6436 || Acc:83.34% *******
# ******* Test speed: 0.007208261710653548s 1/6436 *******
# Epoch 115/300 || Batch 208075/208075 || Loss:0.39670228958129883 || A Batch time:0.1539s || Learning rate:0.00100000 ||
# ******* Prediction 5359/6436 || Acc:83.27% *******
# ******* Test speed: 0.007183339486142876s 1/6436 *******
# Epoch 116/300 || Batch 208075/208075 || Loss:0.39959004521369934 || A Batch time:0.1432s || Learning rate:0.00100000 ||
# ******* Prediction 5361/6436 || Acc:83.30% *******
# ******* Test speed: 0.007079481522884333s 1/6436 *******
# Epoch 117/300 || Batch 208075/208075 || Loss:0.3728318214416504 || A Batch time:0.1369s || Learning rate:0.00100000 ||
# ******* Prediction 5360/6436 || Acc:83.28% *******
# ******* Test speed: 0.007040727427466602s 1/6436 *******
# Epoch 118/300 || Batch 208075/208075 || Loss:0.35960692167282104 || A Batch time:0.1426s || Learning rate:0.00100000 ||
# ******* Prediction 5369/6436 || Acc:83.42% *******
# ******* Test speed: 0.00713510688155834s 1/6436 *******
# Epoch 119/300 || Batch 208075/208075 || Loss:0.4106314480304718 || A Batch time:0.1620s || Learning rate:0.00100000 ||
# ******* Prediction 5358/6436 || Acc:83.25% *******
# ******* Test speed: 0.007148326702781758s 1/6436 *******
# Epoch 120/300 || Batch 208075/208075 || Loss:0.4024125039577484 || A Batch time:0.1478s || Learning rate:0.00100000 ||
# ******* Prediction 5360/6436 || Acc:83.28% *******
# ******* Test speed: 0.007137900853912752s 1/6436 *******
# Epoch 121/300 || Batch 208075/208075 || Loss:0.3857198655605316 || A Batch time:0.1433s || Learning rate:0.00100000 ||
# ******* Prediction 5363/6436 || Acc:83.33% *******
# ******* Test speed: 0.007071189735156546s 1/6436 *******
# Epoch 122/300 || Batch 208075/208075 || Loss:0.3612101972103119 || A Batch time:0.1430s || Learning rate:0.00100000 ||
# ******* Prediction 5361/6436 || Acc:83.30% *******
# ******* Test speed: 0.00714134843991068s 1/6436 *******
# Epoch 123/300 || Batch 208075/208075 || Loss:0.3784196674823761 || A Batch time:0.1421s || Learning rate:0.00100000 ||
# ******* Prediction 5378/6436 || Acc:83.56% *******
# ******* Test speed: 0.007239295393135919s 1/6436 *******
# Epoch 124/300 || Batch 208075/208075 || Loss:0.35227087140083313 || A Batch time:0.1420s || Learning rate:0.00100000 ||
# ******* Prediction 5370/6436 || Acc:83.44% *******
# ******* Test speed: 0.007099520908222945s 1/6436 *******
# Epoch 125/300 || Batch 208075/208075 || Loss:0.3490767776966095 || A Batch time:0.1377s || Learning rate:0.00100000 ||
# ******* Prediction 5371/6436 || Acc:83.45% *******
# ******* Test speed: 0.0072442116464718s 1/6436 *******
# Epoch 126/300 || Batch 208075/208075 || Loss:0.3462781012058258 || A Batch time:0.1409s || Learning rate:0.00100000 ||
# ******* Prediction 5354/6436 || Acc:83.19% *******
# ******* Test speed: 0.0071144428884412575s 1/6436 *******
# Epoch 127/300 || Batch 208075/208075 || Loss:0.33311620354652405 || A Batch time:0.1403s || Learning rate:0.00100000 ||
# ******* Prediction 5382/6436 || Acc:83.62% *******
# ******* Test speed: 0.007034797006100879s 1/6436 *******
# Epoch 128/300 || Batch 208075/208075 || Loss:0.3574073314666748 || A Batch time:0.1422s || Learning rate:0.00100000 ||
# ******* Prediction 5373/6436 || Acc:83.48% *******
# ******* Test speed: 0.006956636461135836s 1/6436 *******
# Epoch 129/300 || Batch 208075/208075 || Loss:0.364734411239624 || A Batch time:0.1438s || Learning rate:0.00100000 ||
# ******* Prediction 5367/6436 || Acc:83.39% *******
# ******* Test speed: 0.007113678215304245s 1/6436 *******
# Epoch 130/300 || Batch 208075/208075 || Loss:0.33221355080604553 || A Batch time:0.1451s || Learning rate:0.00100000 ||
# ******* Prediction 5361/6436 || Acc:83.30% *******
# ******* Test speed: 0.006995709324712854s 1/6436 *******
# Epoch 131/300 || Batch 208075/208075 || Loss:0.3125489056110382 || A Batch time:0.1410s || Learning rate:0.00100000 ||
# ******* Prediction 5374/6436 || Acc:83.50% *******
# ******* Test speed: 0.0070419907940330526s 1/6436 *******
# Epoch 132/300 || Batch 208075/208075 || Loss:0.32344651222229004 || A Batch time:0.1373s || Learning rate:0.00100000 ||
# ******* Prediction 5358/6436 || Acc:83.25% *******
# ******* Test speed: 0.0070674456077158415s 1/6436 *******
# Epoch 133/300 || Batch 208075/208075 || Loss:0.34785202145576477 || A Batch time:0.1435s || Learning rate:0.00100000 ||
# ******* Prediction 5370/6436 || Acc:83.44% *******
# ******* Test speed: 0.007205688486638611s 1/6436 *******
# Epoch 134/300 || Batch 208075/208075 || Loss:0.32382720708847046 || A Batch time:0.1418s || Learning rate:0.00100000 ||
# ******* Prediction 5381/6436 || Acc:83.61% *******
# ******* Test speed: 0.007126472839440819s 1/6436 *******
# Epoch 135/300 || Batch 208075/208075 || Loss:0.3348742425441742 || A Batch time:0.1717s || Learning rate:0.00100000 ||
# ******* Prediction 5355/6436 || Acc:83.20% *******
# ******* Test speed: 0.007084342839185905s 1/6436 *******
# Epoch 136/300 || Batch 208075/208075 || Loss:0.34900540113449097 || A Batch time:0.1424s || Learning rate:0.00100000 ||
# ******* Prediction 5356/6436 || Acc:83.22% *******
# ******* Test speed: 0.007267717584606429s 1/6436 *******
# Epoch 137/300 || Batch 208075/208075 || Loss:0.33943650126457214 || A Batch time:0.1365s || Learning rate:0.00100000 ||
# ******* Prediction 5354/6436 || Acc:83.19% *******
# ******* Test speed: 0.007131786098978103s 1/6436 *******
# Epoch 138/300 || Batch 208075/208075 || Loss:0.3559052050113678 || A Batch time:0.1541s || Learning rate:0.00100000 ||
# ******* Prediction 5360/6436 || Acc:83.28% *******
# ******* Test speed: 0.007090032137722017s 1/6436 *******
# Epoch 139/300 || Batch 208075/208075 || Loss:0.3477730453014374 || A Batch time:0.1369s || Learning rate:0.00100000 ||
# ******* Prediction 5336/6436 || Acc:82.91% *******
# ******* Test speed: 0.006975798409795672s 1/6436 *******
# Epoch 140/300 || Batch 208075/208075 || Loss:0.36667606234550476 || A Batch time:0.1549s || Learning rate:0.00100000 ||
# ******* Prediction 5358/6436 || Acc:83.25% *******
# ******* Test speed: 0.007059851998198173s 1/6436 *******
# Epoch 141/300 || Batch 208075/208075 || Loss:0.365007609128952 || A Batch time:0.1378s || Learning rate:0.00100000 ||
# ******* Prediction 5366/6436 || Acc:83.37% *******
# ******* Test speed: 0.007172814394984651s 1/6436 *******
# Epoch 142/300 || Batch 208075/208075 || Loss:0.38184088468551636 || A Batch time:0.1416s || Learning rate:0.00100000 ||
# ******* Prediction 5356/6436 || Acc:83.22% *******
# ******* Test speed: 0.007035437617115237s 1/6436 *******
# Epoch 143/300 || Batch 208075/208075 || Loss:0.40428659319877625 || A Batch time:0.1555s || Learning rate:0.00100000 ||
# ******* Prediction 5344/6436 || Acc:83.03% *******
# ******* Test speed: 0.007110508722574389s 1/6436 *******
# Epoch 144/300 || Batch 208075/208075 || Loss:0.39203736186027527 || A Batch time:0.1428s || Learning rate:0.00100000 ||
# ******* Prediction 5359/6436 || Acc:83.27% *******
# ******* Test speed: 0.007165135286697473s 1/6436 *******
# Epoch 145/300 || Batch 208075/208075 || Loss:0.3741193115711212 || A Batch time:0.1422s || Learning rate:0.00100000 ||
# ******* Prediction 5362/6436 || Acc:83.31% *******
# ******* Test speed: 0.007143502134651483s 1/6436 *******
# Epoch 146/300 || Batch 208075/208075 || Loss:0.38366439938545227 || A Batch time:0.1371s || Learning rate:0.00100000 ||
# ******* Prediction 5355/6436 || Acc:83.20% *******
# ******* Test speed: 0.007113206416201784s 1/6436 *******
# Epoch 147/300 || Batch 208075/208075 || Loss:0.41459929943084717 || A Batch time:0.1550s || Learning rate:0.00100000 ||
# ******* Prediction 5352/6436 || Acc:83.16% *******
# ******* Test speed: 0.007157527489125765s 1/6436 *******
# Epoch 148/300 || Batch 208075/208075 || Loss:0.37706559896469116 || A Batch time:0.1434s || Learning rate:0.00100000 ||
# ******* Prediction 5362/6436 || Acc:83.31% *******
# ******* Test speed: 0.007167167216076326s 1/6436 *******
# Epoch 149/300 || Batch 208075/208075 || Loss:0.3695860505104065 || A Batch time:0.1369s || Learning rate:0.00100000 ||
# ******* Prediction 5342/6436 || Acc:83.00% *******
# ******* Test speed: 0.007121627118885332s 1/6436 *******
# Epoch 150/300 || Batch 208075/208075 || Loss:0.40311098098754883 || A Batch time:0.1360s || Learning rate:0.00100000 ||
# ******* Prediction 5355/6436 || Acc:83.20% *******
# ******* Test speed: 0.007151761619551275s 1/6436 *******
# Epoch 151/300 || Batch 208075/208075 || Loss:0.39440783858299255 || A Batch time:0.1437s || Learning rate:0.00100000 ||
# ******* Prediction 5344/6436 || Acc:83.03% *******
# ******* Test speed: 0.007089715962679657s 1/6436 *******
# Epoch 152/300 || Batch 208075/208075 || Loss:0.37369608879089355 || A Batch time:0.1418s || Learning rate:0.00100000 ||
# ******* Prediction 5352/6436 || Acc:83.16% *******
# ******* Test speed: 0.007052023489331517s 1/6436 *******
# Epoch 153/300 || Batch 208075/208075 || Loss:0.3772432506084442 || A Batch time:0.1536s || Learning rate:0.00100000 ||
# ******* Prediction 5350/6436 || Acc:83.13% *******
# ******* Test speed: 0.007233810358124538s 1/6436 *******
# Epoch 154/300 || Batch 208075/208075 || Loss:0.39607110619544983 || A Batch time:0.1421s || Learning rate:0.00100000 ||
# ******* Prediction 5345/6436 || Acc:83.05% *******
# ******* Test speed: 0.007082284348880822s 1/6436 *******
# Epoch 155/300 || Batch 208075/208075 || Loss:0.3663148880004883 || A Batch time:0.1419s || Learning rate:0.00100000 ||
# ******* Prediction 5346/6436 || Acc:83.06% *******
# ******* Test speed: 0.007202374853652186s 1/6436 *******
# Epoch 156/300 || Batch 208075/208075 || Loss:0.381314218044281 || A Batch time:0.1418s || Learning rate:0.00100000 ||
# ******* Prediction 5343/6436 || Acc:83.02% *******
# ******* Test speed: 0.007098799169693325s 1/6436 *******
# Epoch 157/300 || Batch 208075/208075 || Loss:0.40498417615890503 || A Batch time:0.1426s || Learning rate:0.00100000 ||
# ******* Prediction 5356/6436 || Acc:83.22% *******
# ******* Test speed: 0.007042151196837203s 1/6436 *******
# Epoch 158/300 || Batch 208075/208075 || Loss:0.38187140226364136 || A Batch time:0.1422s || Learning rate:0.00100000 ||
# ******* Prediction 5350/6436 || Acc:83.13% *******
# ******* Test speed: 0.007201883346861086s 1/6436 *******
# Epoch 159/300 || Batch 208075/208075 || Loss:0.38214337825775146 || A Batch time:0.1384s || Learning rate:0.00100000 ||
# ******* Prediction 5362/6436 || Acc:83.31% *******
# ******* Test speed: 0.007266225319904449s 1/6436 *******
# Epoch 160/300 || Batch 208075/208075 || Loss:0.3723098337650299 || A Batch time:0.1412s || Learning rate:0.00100000 ||
# ******* Prediction 5361/6436 || Acc:83.30% *******
# ******* Test speed: 0.007173204881349211s 1/6436 *******
# Epoch 161/300 || Batch 208075/208075 || Loss:0.4170621633529663 || A Batch time:0.1428s || Learning rate:0.00100000 ||
# ******* Prediction 5355/6436 || Acc:83.20% *******
# ******* Test speed: 0.00720608675235395s 1/6436 *******
# Epoch 162/300 || Batch 208075/208075 || Loss:0.37315189838409424 || A Batch time:0.1371s || Learning rate:0.00100000 ||
# ******* Prediction 5348/6436 || Acc:83.10% *******
# ******* Test speed: 0.007105184608990543s 1/6436 *******
# Epoch 163/300 || Batch 47360/208075 || Loss:0.2934911847114563 || A Batch time:0.1415s || Learning rate:0.00100000 ||
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3412004/2201703483.py in <module>
#      33                                   logit_length=logit_length,
#      34                                   logits_time_major=True,
# ---> 35                                   blank_index=len(CHARS) - 1)
#      36             loss = tf.reduce_mean(loss)
#      37         grads = tape.gradient(loss, lprnet.variables)
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/ctc_ops.py in ctc_loss_v3(labels, logits, label_length, logit_length, logits_time_major, unique, blank_index, name)
#     934       unique=unique,
#     935       blank_index=blank_index,
# --> 936       name=name)
#     937
#     938
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/ctc_ops.py in ctc_loss_dense(labels, logits, label_length, logit_length, logits_time_major, unique, blank_index, name)
#    1060       return result[0], grad
#    1061
# -> 1062     return compute_ctc_loss(*args)
#    1063
#    1064
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/custom_gradient.py in __call__(self, *a, **k)
#     259
#     260   def __call__(self, *a, **k):
# --> 261     return self._d(self._f, a, k)
#     262
#     263
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/custom_gradient.py in decorated(wrapped, args, kwargs)
#     213
#     214     if context.executing_eagerly():
# --> 215       return _eager_mode_decorator(wrapped, args, kwargs)
#     216     else:
#     217       return _graph_mode_decorator(wrapped, args, kwargs)
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/custom_gradient.py in _eager_mode_decorator(f, args, kwargs)
#     437   """Implement custom gradient decorator for eager mode."""
#     438   with tape_lib.VariableWatcher() as variable_watcher:
# --> 439     result, grad_fn = f(*args, **kwargs)
#     440   args = nest.flatten(args)
#     441   all_inputs = list(args) + list(kwargs.values())
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/ctc_ops.py in compute_ctc_loss(logits_t, labels_t, label_length_t, logit_length_t, *unique_t)
#    1052       if unique_t:
#    1053         kwargs["unique"] = unique_t
# -> 1054       result = ctc_loss_and_grad(**kwargs)
#    1055       def grad(grad_loss):
#    1056         grad = [array_ops.reshape(grad_loss, [1, -1, 1]) * result[1]]
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/ctc_ops.py in ctc_loss_and_grad(logits, labels, label_length, logit_length, unique)
#     664       final_state_log_probs=final_state_log_probs,
#     665       observed_log_probs=state_log_probs,
# --> 666       sequence_length=logit_length)
#     667
#     668   if unique:
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/ctc_ops.py in _forward_backward_log(state_trans_log_probs, initial_state_log_probs, final_state_log_probs, observed_log_probs, sequence_length)
#    1268
#    1269   fwd = _scan(
# -> 1270       _forward, observed_log_probs, initial_state_log_probs, inclusive=True)
#    1271
#    1272   def _backward(accs, elems):
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/ctc_ops.py in _scan(fn, elems, initial, reverse, inclusive, final_only)
#    1417     loop_results = loop_in
#    1418     while cond(*loop_results):
# -> 1419       loop_results = body(*loop_results)
#    1420   else:
#    1421     # TODO(tombagby): Update to while_v2.
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/ctc_ops.py in body(i, num_elems, *args)
#    1389       new_out = [
#    1390           inplace_ops.alias_inplace_update(x, update_i, y)
# -> 1391           for x, y in zip(out, flat_accum)
#    1392       ]
#    1393     i = i - 1 if reverse else i + 1
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/ctc_ops.py in <listcomp>(.0)
#    1389       new_out = [
#    1390           inplace_ops.alias_inplace_update(x, update_i, y)
# -> 1391           for x, y in zip(out, flat_accum)
#    1392       ]
#    1393     i = i - 1 if reverse else i + 1
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     335               'in a future version' if date is None else ('after %s' % date),
#     336               instructions)
# --> 337       return func(*args, **kwargs)
#     338
#     339     doc_controls.set_deprecated(new_func)
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/inplace_ops.py in alias_inplace_update(x, i, v)
#      88
#      89   """
# ---> 90   return _inplace_helper(x, i, v, gen_array_ops.inplace_update)
#      91
#      92
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/inplace_ops.py in _inplace_helper(x, i, v, op)
#      61   if i.get_shape().ndims == 0:
#      62     # Single 0-dim update.
# ---> 63     return op(x, array_ops.reshape(i, [1]), array_ops.expand_dims(v, 0))
#      64   return op(x, i, v)
#      65
#
# ~/miniconda3/envs/tf25/lib/python3.7/site-packages/tensorflow/python/ops/gen_array_ops.py in inplace_update(x, i, v, name)
#    4291     try:
#    4292       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 4293         _ctx, "InplaceUpdate", name, x, i, v)
#    4294       return _result
#    4295     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
