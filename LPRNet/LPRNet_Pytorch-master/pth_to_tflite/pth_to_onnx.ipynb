# %%
import io
import torch
import torch.onnx

# %%
pthfile ='./LPRNet_Acc_85.pth'

# %%
lprnet = torch.load(pthfile, map_location='cpu')
#lprnet.load_state_dict(lprnet['state_dict'])

# %%
dummy_input = torch.randn(1, 3, 24, 94)
input_names = [ 'input' ]
output_names = [ 'output' ]
print(lprnet)
# Out:
# LPRNet(
#   (input): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1))
#   (ly1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ly2): ReLU()
#   (ly3): MaxPool3d(kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=0, dilation=1, ceil_mode=False)
#   (ly4): small_basic_block(
#     (block): Sequential(
#       (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (3): ReLU()
#       (4): Conv2d(32, 32, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#       (5): ReLU()
#       (6): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (ly5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ly6): ReLU()
#   (ly7): MaxPool3d(kernel_size=(1, 3, 3), stride=(2, 1, 2), padding=0, dilation=1, ceil_mode=False)
#   (ly8): small_basic_block(
#     (block): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#       (5): ReLU()
#       (6): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (ly9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ly10): ReLU()
#   (ly11): small_basic_block(
#     (block): Sequential(
#       (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#       (5): ReLU()
#       (6): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (ly12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ly13): ReLU()
#   (ly14): MaxPool3d(kernel_size=(1, 3, 3), stride=(4, 1, 2), padding=0, dilation=1, ceil_mode=False)
#   (ly15): Dropout(p=0.5, inplace=False)
#   (ly16): Conv2d(64, 256, kernel_size=(1, 4), stride=(1, 1))
#   (ly17): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ly18): ReLU()
#   (ly19): Dropout(p=0.5, inplace=False)
#   (ly20): Conv2d(256, 68, kernel_size=(13, 1), stride=(1, 1))
#   (ly21): BatchNorm2d(68, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (ly22): ReLU()
#   (ly23): Conv2d(516, 68, kernel_size=(1, 1), stride=(1, 1))
#   (ap1): AvgPool2d(kernel_size=5, stride=5, padding=0)
#   (ap2): AvgPool2d(kernel_size=(4, 10), stride=(4, 2), padding=0)
#   (square): square()
#   (mean): mean()
#   (div): div()
#   (cat): cat()
#   (output): mean2()
# )

# %%
torch.onnx.export(lprnet, dummy_input, "./lprnet_acc85.onnx", verbose=True, input_names=input_names, output_names=output_names)
# Out:
# graph(%input : Float(1, 3, 24, 94),
#       %input.weight : Float(64, 3, 3, 3),
#       %input.bias : Float(64),
#       %ly1.weight : Float(64),
#       %ly1.bias : Float(64),
#       %ly1.running_mean : Float(64),
#       %ly1.running_var : Float(64),
#       %ly4.block.0.weight : Float(32, 64, 1, 1),
#       %ly4.block.0.bias : Float(32),
#       %ly4.block.2.weight : Float(32, 32, 3, 1),
#       %ly4.block.2.bias : Float(32),
#       %ly4.block.4.weight : Float(32, 32, 1, 3),
#       %ly4.block.4.bias : Float(32),
#       %ly4.block.6.weight : Float(128, 32, 1, 1),
#       %ly4.block.6.bias : Float(128),
#       %ly5.weight : Float(128),
#       %ly5.bias : Float(128),
#       %ly5.running_mean : Float(128),
#       %ly5.running_var : Float(128),
#       %ly8.block.0.weight : Float(64, 64, 1, 1),
#       %ly8.block.0.bias : Float(64),
#       %ly8.block.2.weight : Float(64, 64, 3, 1),
#       %ly8.block.2.bias : Float(64),
#       %ly8.block.4.weight : Float(64, 64, 1, 3),
#       %ly8.block.4.bias : Float(64),
#       %ly8.block.6.weight : Float(256, 64, 1, 1),
#       %ly8.block.6.bias : Float(256),
#       %ly9.weight : Float(256),
#       %ly9.bias : Float(256),
#       %ly9.running_mean : Float(256),
#       %ly9.running_var : Float(256),
#       %ly11.block.0.weight : Float(64, 256, 1, 1),
#       %ly11.block.0.bias : Float(64),
#       %ly11.block.2.weight : Float(64, 64, 3, 1),
#       %ly11.block.2.bias : Float(64),
#       %ly11.block.4.weight : Float(64, 64, 1, 3),
#       %ly11.block.4.bias : Float(64),
#       %ly11.block.6.weight : Float(256, 64, 1, 1),
#       %ly11.block.6.bias : Float(256),
#       %ly12.weight : Float(256),
#       %ly12.bias : Float(256),
#       %ly12.running_mean : Float(256),
#       %ly12.running_var : Float(256),
#       %ly16.weight : Float(256, 64, 1, 4),
#       %ly16.bias : Float(256),
#       %ly17.weight : Float(256),
#       %ly17.bias : Float(256),
#       %ly17.running_mean : Float(256),
#       %ly17.running_var : Float(256),
#       %ly20.weight : Float(68, 256, 13, 1),
#       %ly20.bias : Float(68),
#       %ly21.weight : Float(68),
#       %ly21.bias : Float(68),
#       %ly21.running_mean : Float(68),
#       %ly21.running_var : Float(68),
#       %ly23.weight : Float(68, 516, 1, 1),
#       %ly23.bias : Float(68),
#       %131 : Float(),
#       %132 : Float(),
#       %133 : Float(),
#       %134 : Float()):
#   %63 : Float(1, 64, 22, 92) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[0, 0, 0, 0], strides=[1, 1]](%input, %input.weight, %input.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %64 : Float(1, 64, 22, 92) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%63, %ly1.weight, %ly1.bias, %ly1.running_mean, %ly1.running_var) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %65 : Float(1, 64, 22, 92) = onnx::Relu(%64) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %66 : Float(1, 64, 20, 90) = onnx::MaxPool[kernel_shape=[1, 3, 3], pads=[0, 0, 0, 0, 0, 0], strides=[1, 1, 1]](%65) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:582:0
#   %67 : Float(1, 32, 20, 90) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%66, %ly4.block.0.weight, %ly4.block.0.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %68 : Float(1, 32, 20, 90) = onnx::Relu(%67) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %69 : Float(1, 32, 20, 90) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 1], pads=[1, 0, 1, 0], strides=[1, 1]](%68, %ly4.block.2.weight, %ly4.block.2.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %70 : Float(1, 32, 20, 90) = onnx::Relu(%69) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %71 : Float(1, 32, 20, 90) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 3], pads=[0, 1, 0, 1], strides=[1, 1]](%70, %ly4.block.4.weight, %ly4.block.4.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %72 : Float(1, 32, 20, 90) = onnx::Relu(%71) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %73 : Float(1, 128, 20, 90) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%72, %ly4.block.6.weight, %ly4.block.6.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %74 : Float(1, 128, 20, 90) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%73, %ly5.weight, %ly5.bias, %ly5.running_mean, %ly5.running_var) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %75 : Float(1, 128, 20, 90) = onnx::Relu(%74) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %76 : Float(1, 64, 18, 44) = onnx::MaxPool[kernel_shape=[1, 3, 3], pads=[0, 0, 0, 0, 0, 0], strides=[2, 1, 2]](%75) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:582:0
#   %77 : Float(1, 64, 18, 44) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%76, %ly8.block.0.weight, %ly8.block.0.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %78 : Float(1, 64, 18, 44) = onnx::Relu(%77) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %79 : Float(1, 64, 18, 44) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 1], pads=[1, 0, 1, 0], strides=[1, 1]](%78, %ly8.block.2.weight, %ly8.block.2.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %80 : Float(1, 64, 18, 44) = onnx::Relu(%79) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %81 : Float(1, 64, 18, 44) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 3], pads=[0, 1, 0, 1], strides=[1, 1]](%80, %ly8.block.4.weight, %ly8.block.4.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %82 : Float(1, 64, 18, 44) = onnx::Relu(%81) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %83 : Float(1, 256, 18, 44) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%82, %ly8.block.6.weight, %ly8.block.6.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %84 : Float(1, 256, 18, 44) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%83, %ly9.weight, %ly9.bias, %ly9.running_mean, %ly9.running_var) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %85 : Float(1, 256, 18, 44) = onnx::Relu(%84) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %86 : Float(1, 64, 18, 44) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%85, %ly11.block.0.weight, %ly11.block.0.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %87 : Float(1, 64, 18, 44) = onnx::Relu(%86) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %88 : Float(1, 64, 18, 44) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 1], pads=[1, 0, 1, 0], strides=[1, 1]](%87, %ly11.block.2.weight, %ly11.block.2.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %89 : Float(1, 64, 18, 44) = onnx::Relu(%88) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %90 : Float(1, 64, 18, 44) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 3], pads=[0, 1, 0, 1], strides=[1, 1]](%89, %ly11.block.4.weight, %ly11.block.4.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %91 : Float(1, 64, 18, 44) = onnx::Relu(%90) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %92 : Float(1, 256, 18, 44) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%91, %ly11.block.6.weight, %ly11.block.6.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %93 : Float(1, 256, 18, 44) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%92, %ly12.weight, %ly12.bias, %ly12.running_mean, %ly12.running_var) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %94 : Float(1, 256, 18, 44) = onnx::Relu(%93) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %95 : Float(1, 64, 16, 21) = onnx::MaxPool[kernel_shape=[1, 3, 3], pads=[0, 0, 0, 0, 0, 0], strides=[4, 1, 2]](%94) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:936:0
#   %96 : Float(1, 256, 16, 18) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 4], pads=[0, 0, 0, 0], strides=[1, 1]](%95, %ly16.weight, %ly16.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %97 : Float(1, 256, 16, 18) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%96, %ly17.weight, %ly17.bias, %ly17.running_mean, %ly17.running_var) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %98 : Float(1, 256, 16, 18) = onnx::Relu(%97) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:936:0
#   %99 : Float(1, 68, 4, 18) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[13, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%98, %ly20.weight, %ly20.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %100 : Float(1, 68, 4, 18) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%99, %ly21.weight, %ly21.bias, %ly21.running_mean, %ly21.running_var) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %101 : Float(1, 68, 4, 18) = onnx::Relu(%100) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/functional.py:1063:0
#   %102 : Tensor = onnx::Pad[mode="constant", pads=[0, 0, 0, 0, 0, 0, 0, 0], value=0.](%65)
#   %103 : Float(1, 64, 4, 18) = onnx::AveragePool[kernel_shape=[5, 5], pads=[0, 0, 0, 0], strides=[5, 5]](%102) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/pooling.py:554:0
#   %106 : Float(1, 64, 4, 18) = onnx::Pow(%103, %131) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:25:0
#   %107 : Float() = onnx::ReduceMean[keepdims=0](%106) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:31:0
#   %108 : Float(1, 64, 4, 18) = onnx::Div(%103, %107) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:43:0
#   %109 : Tensor = onnx::Pad[mode="constant", pads=[0, 0, 0, 0, 0, 0, 0, 0], value=0.](%75)
#   %110 : Float(1, 128, 4, 18) = onnx::AveragePool[kernel_shape=[5, 5], pads=[0, 0, 0, 0], strides=[5, 5]](%109) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/pooling.py:554:0
#   %113 : Float(1, 128, 4, 18) = onnx::Pow(%110, %132) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:25:0
#   %114 : Float() = onnx::ReduceMean[keepdims=0](%113) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:31:0
#   %115 : Float(1, 128, 4, 18) = onnx::Div(%110, %114) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:43:0
#   %116 : Tensor = onnx::Pad[mode="constant", pads=[0, 0, 0, 0, 0, 0, 0, 0], value=0.](%94)
#   %117 : Float(1, 256, 4, 18) = onnx::AveragePool[kernel_shape=[4, 10], pads=[0, 0, 0, 0], strides=[4, 2]](%116) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/pooling.py:554:0
#   %120 : Float(1, 256, 4, 18) = onnx::Pow(%117, %133) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:25:0
#   %121 : Float() = onnx::ReduceMean[keepdims=0](%120) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:31:0
#   %122 : Float(1, 256, 4, 18) = onnx::Div(%117, %121) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:43:0
#   %125 : Float(1, 68, 4, 18) = onnx::Pow(%101, %134) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:25:0
#   %126 : Float() = onnx::ReduceMean[keepdims=0](%125) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:31:0
#   %127 : Float(1, 68, 4, 18) = onnx::Div(%101, %126) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:134:0
#   %128 : Float(1, 516, 4, 18) = onnx::Concat[axis=1](%108, %115, %122, %127) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:49:0
#   %129 : Float(1, 68, 4, 18) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%128, %ly23.weight, %ly23.bias) # /home/luxian/anaconda3/envs/pth-tf/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %output : Float(1, 68, 18) = onnx::ReduceMean[axes=[2], keepdims=0](%129) # /home/luxian/tf/projects/LPRNet/LPRNet_Pytorch-master/pth_to_tflite/model/LPRNet.py:37:0
#   return (%output)
